# %% [markdown]
# # Python 下載XML檔案與解析
#
#
# * 了解 xml 檔案格式與內容
# * 能夠利用套件存取 xml 格式的檔案

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「File I/O」與「xmltodict」讀出來的內容有什麼差異
#
# * 根據範例檔案的結果：
#     1. 請問高雄市有多少地區有溫度資料？
#     2. 請取出每一個地區所記錄的第一個時間點跟溫度
#     3. 請取出第一個地區所記錄的每一個時間點跟溫度

# %% [markdown]
# ### 比較一下範例檔案中的「File I/O」與「xmltodict」讀出來的內容有什麼差異

# %%
'''
file i/o讀出來會有標籤，xmltodict讀出來的會將標籤濾掉，並顯示相關標籤的值
'''

# %% [markdown]
# ### 根據範例檔案的結果：
#
# 1. 請問高雄市有多少地區有溫度資料？
# 2. 請取出每一個地區所記錄的第一個時間點跟溫度
# 3. 請取出第一個地區所記錄的每一個時間點跟溫度

# %%
# 1. 請問高雄市有多少地區有溫度資料？
import xmltodict
d = dict(xmltodict.parse(xml))
fh = open("./data/64_72hr_CH.xml", "r",encoding='utf-8')
xml = fh.read()
fh.close()

locations = d['cwbopendata']['dataset']['locations']['location']
print(len(locations))
# Out:
# 38

# %%
# 2. 請取出每一個地區所記錄的第一個時間點跟溫度
for location in locations:
    print(location['locationName'])
    print(location['weatherElement'][0]['time'][0]['dataTime'] )
    print(location['weatherElement'][0]['time'][0]['elementValue']['value'] )
# Out:
# 鹽埕區
# 2019-11-24T00:00:00+08:00
# 24
# 鼓山區
# 2019-11-24T00:00:00+08:00
# 24
# 左營區
# 2019-11-24T00:00:00+08:00
# 23
# 楠梓區
# 2019-11-24T00:00:00+08:00
# 23
# 三民區
# 2019-11-24T00:00:00+08:00
# 24
# 新興區
# 2019-11-24T00:00:00+08:00
# 24
# 前金區
# 2019-11-24T00:00:00+08:00
# 24
# 苓雅區
# 2019-11-24T00:00:00+08:00
# 24
# 前鎮區
# 2019-11-24T00:00:00+08:00
# 24
# 旗津區
# 2019-11-24T00:00:00+08:00
# 24
# 小港區
# 2019-11-24T00:00:00+08:00
# 24
# 鳳山區
# 2019-11-24T00:00:00+08:00
# 23
# 林園區
# 2019-11-24T00:00:00+08:00
# 24
# 大寮區
# 2019-11-24T00:00:00+08:00
# 24
# 大樹區
# 2019-11-24T00:00:00+08:00
# 22
# 大社區
# 2019-11-24T00:00:00+08:00
# 22
# 仁武區
# 2019-11-24T00:00:00+08:00
# 22
# 鳥松區
# 2019-11-24T00:00:00+08:00
# 22
# 岡山區
# 2019-11-24T00:00:00+08:00
# 22
# 橋頭區
# 2019-11-24T00:00:00+08:00
# 23
# 燕巢區
# 2019-11-24T00:00:00+08:00
# 22
# 田寮區
# 2019-11-24T00:00:00+08:00
# 21
# 阿蓮區
# 2019-11-24T00:00:00+08:00
# 21
# 路竹區
# 2019-11-24T00:00:00+08:00
# 22
# 湖內區
# 2019-11-24T00:00:00+08:00
# 22
# 茄萣區
# ...

# %%
# 3. 請取出第一個地區所記錄的每一個時間點跟溫度
location=locations[0]
for l in location['weatherElement'][0]['time']:
    print(l['dataTime'] )
    print(l['elementValue']['value'] )
# Out:
# 2019-11-24T00:00:00+08:00
# 24
# 2019-11-24T03:00:00+08:00
# 23
# 2019-11-24T06:00:00+08:00
# 22
# 2019-11-24T09:00:00+08:00
# 24
# 2019-11-24T12:00:00+08:00
# 28
# 2019-11-24T15:00:00+08:00
# 28
# 2019-11-24T18:00:00+08:00
# 26
# 2019-11-24T21:00:00+08:00
# 25
# 2019-11-25T00:00:00+08:00
# 24
# 2019-11-25T03:00:00+08:00
# 23
# 2019-11-25T06:00:00+08:00
# 22
# 2019-11-25T09:00:00+08:00
# 24
# 2019-11-25T12:00:00+08:00
# 27
# 2019-11-25T15:00:00+08:00
# 27
# 2019-11-25T18:00:00+08:00
# 25
# 2019-11-25T21:00:00+08:00
# 24
# 2019-11-26T00:00:00+08:00
# 23
# 2019-11-26T03:00:00+08:00
# 22
# 2019-11-26T06:00:00+08:00
# 22
# 2019-11-26T09:00:00+08:00
# 23
# 2019-11-26T12:00:00+08:00
# 25
# 2019-11-26T15:00:00+08:00
# 25
# 2019-11-26T18:00:00+08:00
# 24
# 2019-11-26T21:00:00+08:00
# 23
