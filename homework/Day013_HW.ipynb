# %% [markdown]
# # PTT 網路爬蟲實作練習
#
#
# * 能夠利用 Request + BeatifulSour 撰寫爬蟲，並存放到合適的資料結構

# %% [markdown]
# ## 作業目標
#
# 根據範例 ，完成以下問題：
#
# * ① 印出最新文章的「作者」「標題」「時間」
# * ② 印出第一頁所有文章的「作者」「標題」「時間」

# %% [markdown]
# ### ① 印出最新文章的「作者」「標題」「時間」

# %%
import requests
from bs4 import BeautifulSoup

url='https://www.ptt.cc/bbs/NBA/index.html'
r=requests.get(url)
soup=BeautifulSoup(r.text,'lxml')

items=soup.findAll('div','r-ent')

for item in items:
    title=item.find('div','title').text
    author=item.find('div','author').text
    time=item.find('div','date').text
    print('author :',author)
    print('title :',title)
    print('time :',time)
    break
# Out:
# author : Wall62
# title :
# [情報] 湖人打出自1985-86以來最佳開季戰績
#
# time : 12/12

# %% [markdown]
# ### ② 印出第一頁所有文章的「作者」「標題」「時間」

# %%
import requests
from bs4 import BeautifulSoup

url='https://www.ptt.cc/bbs/NBA/index.html'
r=requests.get(url)
soup=BeautifulSoup(r.text,'lxml')

items=soup.findAll('div','r-ent')

for item in items:
    title=item.find('div','title').text
    author=item.find('div','author').text
    time=item.find('div','date').text
    print('author :',author)
    print('title :',title)
    print('time :',time)
# Out:
# author : Wall62
# title :
# [情報] 湖人打出自1985-86以來最佳開季戰績
#
# time : 12/12
# author : jk182325
# title :
# [新聞] 重回多倫多收下冠軍戒　可愛：離開暴龍是
#
# time : 12/12
# author : whj0530
# title :
# [情報] Tatum:上賽季戰績不佳不是Irving的錯,全
#
# time : 12/12
# author : Rambo
# title :
# [BOX ] Hawks 102:136 Bulls 數據
#
# time : 12/12
# author : Rambo
# title :
# [BOX ] Jazz 127:116 Timberwolves 數據
#
# time : 12/12
# author : NSYSUheng
# title :
# [情報] Harden今日創下多項紀錄、里程碑
#
# time : 12/12
# author : LinBaoYan
# title :
# [新聞] 哈登狂轟55分 第四節隻手逆轉騎士
#
# time : 12/12
# author : guardyo
# title :
# [BOX ] Grizzlies 115:108 Suns
#
# time : 12/12
# author : whoAU
# title :
# [花邊] 可愛重返多倫多領戒指 全場球迷歡呼慶祝
#
# time : 12/12
# author : -
# title :
#
# 				(已被Vedan刪除) <LinBaoYan>及人文
#
#
# time : 12/12
# author : guardyo
# title :
# [BOX ] Pelicans 112:127 Bucks
#
# time : 12/12
# author : melman87
# title :
# [花邊] Hayward：就是頭有點疼 明天會接受檢查
#
# time : 12/12
# author : Vedan
# title :
# [公告] 板規v6.6
#
# time :  5/24
# author : Vedan
# title :
# ...

# %% [markdown]
# ### ③ 試著爬爬看其他版的文章

# %%
import requests
from bs4 import BeautifulSoup

url='https://www.ptt.cc/bbs/Gossiping/index.html'
cookies={'over18':'1'}
r=requests.get(url,cookies=cookies)
soup=BeautifulSoup(r.text,'lxml')

items=soup.findAll('div','r-ent')

for item in items:
    title=item.find('div','title').text
    author=item.find('div','author').text
    time=item.find('div','date').text
    print('author :',author)
    print('title :',title)
    print('time :',time)
# Out:
# author : poeta
# title :
# [問卦] 班群句點王要怎麼改善
#
# time : 12/12
# author : cloud72426
# title :
# Re: [問卦] 女孩子喜歡理工男什麼優點？
#
# time : 12/12
# author : heartblue
# title :
# Re: [問卦] 楊蕙如要做什麼鄉民才會原諒她
#
# time : 12/12
# author : loutt
# title :
# Re: [新聞] 聯醫做假帳？柯文哲怒轟：又是哪個「楊
#
# time : 12/12
# author : deann
# title :
# Re: [新聞] 聯醫做假帳？柯文哲怒轟：又是哪個「楊
#
# time : 12/12
# author : Agguy
# title :
# [新聞] 韓國瑜讓民心思變 洛杉基：肯定贏超過150
#
# time : 12/12
# author : kohanchen
# title :
# [問卦] VoLTE是啥?很好用嗎!?
#
# time : 12/12
# author : three88720
# title :
# [問卦] 海龜的鼻孔是不是日常用品的死亡筆記本
#
# time : 12/12
# author : arsonlolita
# title :
# [公告] 八卦板板規(2019.08.21)
#
# time :  8/21
# author : arsonlolita
# title :
# [公告] 宣導禁止回文政問
#
# time : 11/20
# author : witty
# title :
# [協尋] 11/20高市大順一路548號順明街行車記錄
#
# time : 11/24
# author : Amybook
# title :
# 協尋12/6台中市向上路往精科五路行車記錄器
#
# time : 12/08
# author : Bignana
# title :
# [公告] 一劍無悔，十二月置底閒聊文
#
# time : 12/02
